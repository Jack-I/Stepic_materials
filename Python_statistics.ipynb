# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('states.csv', sep=',')

# %%
x=data["hs_grad"]
y=data["poverty"]
gradient, intercept, r_value, p_value, std_err = stats.linregress(x,y)
mn=np.min(x)
mx=np.max(x)
x1=np.linspace(mn,mx,500)
y1=gradient*x1+intercept
plt.plot(x,y,'ob') #Рассталяем точки
plt.plot(x1,y1,'-r') #Рисуем линию
plt.title("Связь бедности и уровня образования")
plt.xlabel("Уровень образования %")
plt.ylabel("Уровень бедности %")
plt.show() #Рисуем график
stats.linregress (x, y)
# Out:
# LinregressResult(slope=-0.6212167177940106, intercept=64.78096577010209, rvalue=-0.7468582531582505, pvalue=3.10882981031841e-10, stderr=0.0790164710017928)

# %%
import scipy.stats
#from scipy import stats
a=0.53*1500
b=1500-a
stats.chisquare(f_obs=[a,b]) #,ddof=5 ?!
#help(stats.chisquare)
# Out:
# 795.0 705.0
# Power_divergenceResult(statistic=5.4, pvalue=0.02013675155034633)

# %%
#step 1.7
#import scipy.stats
from scipy import stats
chi2,p_val,df,expected=stats.chi2_contingency([[20,15],[11,12],[7,9]])
print(f"Chi square: {chi2}\ndegrees of freedom: {df}\np-value: {p_val}\n\n{expected}")
# Out:
# Chi square: 0.9544070774762996
# degrees of freedom: 2
# p-value: 0.6205162173513055
#
# [[17.97297297 17.02702703]
#  [11.81081081 11.18918919]
#  [ 8.21621622  7.78378378]]

# %%
from itertools import product
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.mosaicplot import mosaic

tuples = list(product(['Placebo', 'Aspirine'], ['Yes', 'No']))
index = pd.MultiIndex.from_tuples(tuples)
data = pd.Series([18,7,6,13], index=index)
#print(pd.pivot_table(?, index=["Group"], columns=["Thrombosis"], aggfunc=lambda x: len(x)))
mosaic(data, title='hierarchical index series')
plt.show()

# %%
#Step 1.8 Точный критерий фишера
from scipy import stats
odds_ratio, p_value = stats.fisher_exact([[1, 3], [3, 1]])  # odds_ratio - отношение шансов
print(p_value)
# Out:
# 0.48571428571428527
